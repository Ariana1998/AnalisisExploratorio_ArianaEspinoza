# %% [markdown]
# ## Notebook Pima Indian Diabetes Dataset

# %% [markdown]
# Se importan las librerias necesarias para utilizar este conjunto de datos

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Se importan los datos en un dataframe

# %%
df = pd.read_csv(r'diabetes.csv')

# %%
# Se imprime el conjunto de datos para tenerlo de forma visual en una lista
print(df)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# En esta grafica podemos ver el nivel de glucosa de las mujeres examinadas con respecto a su edad, viendo asi que las mujeres de aproximadamente
# en sus 22 tienen el nivel mas alto de glucosa.

plt.style.use('bmh')
x = df['Age']
y = df['Glucose']

#Bar chart
plt.xlabel('Edad')
plt.ylabel('Nivel de Glucosa')
plt.bar(x,y)
# Out:
# <BarContainer object of 768 artists>

# %%
# En esta grafica podemos ver que la mayoria de las mujeres en este conjunto de datos tienen un IMC DE 30-34, teniendo asi obesidad de grado 1, 
# mientras que en el siguiente lugar con mayor cantidad de personas tienen un IMC de 35-39 el cual es obesidad tipo 2.
df['BMI'].plot.hist(edgecolor="white")
# Out:
# <Axes: ylabel='Frequency'>

# %%
# Grafica respecto a los embrazos con la edad
Embarazos = df['Age']
Edad = df['Pregnancies']
fig = plt.figure()
Myaxes = fig.add_axes([0.1, 0.1, 1.6, 1.6])
x_ticks = np.arange(0,18)
plt.xticks(x_ticks)
Myaxes.bar(Embarazos,Edad)
# Out:
# <BarContainer object of 768 artists>

# %%
plt.hist(df['Age'])
plt.title('Edad')
plt.xlabel('Edad')
plt.ylabel('Edad')
# Out:
# Text(0, 0.5, 'Edad')

# %%
# Aqui se ejemplifica el numero de embarazos con relacion al estado de la presion arterial
# make data:
x = df['Pregnancies']
y = df['BloodPressure']

# plot
fig, ax = plt.subplots()
ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)
plt.xlabel('Embarazos')
plt.ylabel('Presion Arterial')
plt.show()

# %%
# Aqui se ejemplifica el numero de embarazos con relacion al estado de la presion arterial
# make data:
x = df['Age']
y = df['DiabetesPedigreeFunction']

# plot
fig, ax = plt.subplots()
ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)
plt.xlabel('Edad')
plt.ylabel('Predisposicion diabetica')
plt.show()

# %%
# Numero de embarazos respecto al nivel de insulina
# make data:
x = df['Pregnancies']
y = df['Insulin']

# plot
fig, ax = plt.subplots()
ax.bar(x, y, width=1, edgecolor="white", linewidth=0.7)
plt.show()

# %%
# Prueba
species = ("Adelie", "Chinstrap", "Gentoo")
penguin_means = {
    'Bill Depth': (18.35, 18.43, 14.98),
    'Bill Length': (38.79, 48.83, 47.50),
    'Flipper Length': (189.95, 195.82, 217.19),
}

x = np.arange(len(species))  # the label locations
width = 0.25  # the width of the bars
multiplier = 0

fig, ax = plt.subplots(layout='constrained')

for attribute, measurement in penguin_means.items():
    offset = width * multiplier
    rects = ax.bar(x + offset, measurement, width, label=attribute)
    ax.bar_label(rects, padding=3)
    multiplier += 1

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Length (mm)')
ax.set_title('Penguin attributes by species')
ax.set_xticks(x + width, species)
ax.legend(loc='upper left', ncols=3)
ax.set_ylim(0, 250)

plt.show()

# %%
# Prueba parte mil
# Fixing random state for reproducibility
np.random.seed(19680801)

fig, ax = plt.subplots()

# Example data
people = ('Tom', 'Dick', 'Harry', 'Slim', 'Jim')
y_pos = np.arange(len(people))
performance = 3 + 10 * np.random.rand(len(people))
error = np.random.rand(len(people))

ax.barh(y_pos, performance, xerr=error, align='center')
ax.set_yticks(y_pos, labels=people)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Performance')
ax.set_title('How fast do you want to go today?')

plt.show()
